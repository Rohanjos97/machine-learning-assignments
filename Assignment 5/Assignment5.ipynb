# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohanjos97/machine-learning-assignments/blob/main/Assignment%205/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate the datasets A and B in R2 with each of them consisting 2000 data points from normal distribution. The dataset A and B has been drawn from the N (μ1, Σ1 ) and N( μ2, Σ2 ). Let us fix the μ1 = [-1,1] and μ2 = [1,1].

# %% [markdown]
# ## a. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ##0.6, 0
#
# ## 0, 0.6
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pandas import DataFrame
from sklearn.datasets import make_blobs

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0],
                [0, 0.6]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.027115  0.445579
# 1    -1.160478  1.205521
# 2    -0.822105  1.001702
# 3     0.148778  0.560321
# 4    -0.752233  0.257521
# ...        ...       ...
# 1995 -0.433443  1.241191
# 1996 -0.218132  0.969815
# 1997  0.212876  1.619696
# 1998 -1.335150  1.916879
# 1999 -2.292729  0.414218
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([1, 1])
sd2 = np.array([[0.6, 0],
                [0, 0.6]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     1.967906  2.376476
# 1     0.634861  0.334016
# 2     1.100944  0.909541
# 3     1.417165  0.372547
# 4     1.540706  1.745056
# ...        ...       ...
# 1995 -0.000177  0.466565
# 1996  1.777066  0.522785
# 1997  0.755292  2.017559
# 1998  1.038467  2.266305
# 1999  1.516002  1.897264
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-2,  0])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0., 1.])

# %%
np.dot(W.T, X0)
# Out:
# 0.0

# %% [markdown]
# w1x1 + w2x2 + c = 0
# <br>
# w1 = -2
# <br>
# w2 = 0

# %%
X = np.zeros(100)

Y = np.random.uniform(-3, 4, 100)

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(X, Y, color='black')

# %% [markdown]
# ## b. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ## 0.7, 0
# ##0, 0.3
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.7, 0],
                [0, 0.3]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.963455  2.400497
# 1    -1.628048  0.787490
# 2    -0.781474  0.940410
# 3    -1.158014  0.496200
# 4    -0.877936  1.450602
# ...        ...       ...
# 1995 -1.275311  1.270474
# 1996 -1.018593  0.999368
# 1997  0.264535  0.532227
# 1998  0.009033  1.426220
# 1999 -1.657656  0.596880
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.7, 0],
                [0, 0.3]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     1.357943  1.773179
# 1     1.577842  2.195949
# 2     2.035525  2.502062
# 3     2.421424  1.156535
# 4     2.944397  1.535621
# ...        ...       ...
# 1995  1.990689  1.913733
# 1996  1.826216  1.888887
# 1997  1.799151  1.998212
# 1998  1.869628  1.663641
# 1999  2.896510  1.450915
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-2,  0])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0., 1.])

# %%
np.dot(W.T, X0)
# Out:
# 0.0

# %% [markdown]
# w1x1 + w2x2 + c = 0
# <br>
# w1 = -2
# <br>
# w2 = 0

# %%
X = np.zeros(100)

Y = np.random.uniform(-3, 4, 100)

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(X, Y, color='black')

# %% [markdown]
# ## c. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ## 0.6, 0.25
# ##0.25, 0.4
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0.25],
                [0.25, 0.4]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.648220  1.451332
# 1    -1.763531  1.211974
# 2     0.445392  1.028328
# 3     1.269753  1.804327
# 4    -0.183473  0.985003
# ...        ...       ...
# 1995 -0.215545  1.698005
# 1996 -0.058086  1.064961
# 1997 -0.486400  0.931054
# 1998  0.010968  1.529558
# 1999 -0.970428  1.056726
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.6, 0.25],
                [0.25, 0.4]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     3.086856  3.087945
# 1     2.219347  1.828758
# 2     1.970887  2.553741
# 3     2.854975  1.867206
# 4     1.033464  1.371446
# ...        ...       ...
# 1995  2.157780  2.844243
# 1996  0.995141  1.319696
# 1997  1.785987  1.227681
# 1998  1.709568  1.198400
# 1999  2.722022  2.580320
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-2,  0])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0., 1.])

# %%
np.dot(W.T, X0)
# Out:
# 0.0

# %% [markdown]
# w1x1 + w2x2 + c = 0
# <br>
# w1 = -2
# <br>
# w2 = 0

# %%
X = np.zeros(100)

Y = np.random.uniform(-3, 4, 100)

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(X, Y, color='black')
