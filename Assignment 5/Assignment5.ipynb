# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohanjos97/machine-learning-assignments/blob/main/Assignment%205/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate the datasets A and B in R2 with each of them consisting 2000 data points from normal distribution. The dataset A and B has been drawn from the N (μ1, Σ1 ) and N( μ2, Σ2 ). Let us fix the μ1 = [-1,1] and μ2 = [1,1].

# %% [markdown]
# ## a. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ##0.6, 0
#
# ## 0, 0.6
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pandas import DataFrame
from sklearn.datasets import make_blobs

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0],
                [0, 0.6]])

A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.857248  0.861891
# 1    -0.761006 -0.222414
# 2    -1.951456  0.507281
# 3    -0.585940  0.335136
# 4    -1.276879 -0.447452
# ...        ...       ...
# 1995 -1.174921  1.963888
# 1996 -1.015159  1.135193
# 1997 -1.860276  1.555241
# 1998 -0.940807  0.007136
# 1999 -1.509877  1.780087
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([1, 1])
sd2 = np.array([[0.6, 0],
                [0, 0.6]])

B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     0.233949  0.989701
# 1     1.598980 -0.603087
# 2     0.729864  0.542356
# 3     2.314290  1.416054
# 4     1.539824  1.297808
# ...        ...       ...
# 1995  0.616993  1.680531
# 1996  1.623955  0.951290
# 1997  2.230981  0.644584
# 1998  0.304673  1.166663
# 1999  1.646954  1.433909
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-2,  0])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0., 1.])

# %%
x = np.dot(W.T, X0)

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot([x, x], [-2, 4], color='black')

# %% [markdown]
# ## b. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ## 0.7, 0
# ##0, 0.3
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.7, 0],
                [0, 0.3]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.708155  0.914724
# 1    -2.535322  0.089901
# 2    -1.082509  0.691784
# 3     0.598133  0.098500
# 4    -2.419537  1.078407
# ...        ...       ...
# 1995 -0.430718  1.123848
# 1996 -0.552807  2.251121
# 1997  0.156785  0.530801
# 1998 -0.473635  1.046909
# 1999 -1.113195  1.412827
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.7, 0],
                [0, 0.3]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     3.421228  1.561330
# 1     1.760536  2.650666
# 2     2.608629  1.837399
# 3     3.310074  2.783550
# 4     2.152969  3.110619
# ...        ...       ...
# 1995  2.349411  1.510493
# 1996  3.438731  2.640955
# 1997  2.171963  2.538516
# 1998  3.088728  1.981280
# 1999  1.014012  2.383297
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-3, -1])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0.5, 1.5])

# %%
np.dot(W.T, X0)
# Out:
# -3.0

# %%
x21 = np.linspace([-2, 5], 100)
x22 = (W - W[0] * x21)/W[1]

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(x21, x22, color='black')
axes.set_xlim(-4, 5)
axes.set_ylim(-2, 4.5)
# Out:
# (-2.0, 4.5)

# %% [markdown]
# ## c. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ## 0.6, 0.25
# ##0.25, 0.4
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0.25],
                [0.25, 0.4]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -1.279846  1.532932
# 1    -2.077507  1.281907
# 2    -0.750387  0.899302
# 3    -1.286814  0.036214
# 4    -0.652265  1.431268
# ...        ...       ...
# 1995 -1.320371 -0.184088
# 1996  0.510997  2.002883
# 1997 -0.622071  1.493328
# 1998 -0.823258  1.247673
# 1999 -2.438350  0.281027
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.6, 0.25],
                [0.25, 0.4]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     2.867166  1.837664
# 1     1.858427  1.781426
# 2     1.944973  2.515981
# 3     2.566731  1.631420
# 4     1.113148  2.202144
# ...        ...       ...
# 1995  2.562538  2.015183
# 1996  3.131308  2.187198
# 1997  3.012284  2.571642
# 1998  2.298902  1.211349
# 1999  1.675970  1.126963
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-3, -1])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0.5, 1.5])

# %%
np.dot(W.T, X0)
# Out:
# -3.0

# %%
x31 = np.linspace([-1, 2], 100)
x32 = (W - W[0] * x31)/W[1]

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(x31, x32, color='black')
axes.set_xlim(-4.5, 5)
axes.set_ylim(-1.5, 4.5)
# Out:
# (-1.5, 4.5)
