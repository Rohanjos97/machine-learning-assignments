# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohanjos97/machine-learning-assignments/blob/main/Assignment%205/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate the datasets A and B in R2 with each of them consisting 2000 data points from normal distribution. The dataset A and B has been drawn from the N (μ1, Σ1 ) and N( μ2, Σ2 ). Let us fix the μ1 = [-1,1] and μ2 = [1,1].

# %% [markdown]
# ## a. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ##0.6, 0
#
# ## 0, 0.6
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pandas import DataFrame
from sklearn.datasets import make_blobs

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0],
                [0, 0.6]])

A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.888041  1.271342
# 1    -1.474039  2.081237
# 2    -0.729640  1.403339
# 3    -1.533725  0.938012
# 4    -0.686355 -0.584717
# ...        ...       ...
# 1995 -0.418614  0.714999
# 1996 -1.446835  1.220880
# 1997 -0.354054  0.118350
# 1998 -0.959833  0.661357
# 1999  0.544896  0.679603
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([1, 1])
sd2 = np.array([[0.6, 0],
                [0, 0.6]])

B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     0.663844  0.545823
# 1     0.741306  0.152889
# 2     1.691806  0.954834
# 3     0.903087  0.573580
# 4     1.301857  1.732240
# ...        ...       ...
# 1995  0.247014  2.149576
# 1996  0.180406  0.436599
# 1997 -0.414936  0.802073
# 1998  1.406584  0.034728
# 1999  2.192850  0.891412
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-2,  0])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0., 1.])

# %%
x = np.dot(W.T, X0)
x
# Out:
# 0.0

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot([x, x], [-2, 4], color='black')

# %% [markdown]
# **Conclusion :** Decision boundary is linear in nature and parallel to y-axis.

# %% [markdown]
# ## b. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ## 0.7, 0
# ##0, 0.3
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.7, 0],
                [0, 0.3]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.854031  0.221794
# 1     1.237344  1.241656
# 2    -1.419889  1.471049
# 3    -1.852878  0.909306
# 4    -2.584483  1.104819
# ...        ...       ...
# 1995 -1.303388  1.315189
# 1996 -0.385940  0.992425
# 1997 -1.651668  1.277348
# 1998 -1.005371  1.203300
# 1999 -1.733781  1.318235
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.7, 0],
                [0, 0.3]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     1.796384  2.439721
# 1     0.264834  2.905487
# 2     2.838780  1.859257
# 3     1.066525  2.595304
# 4     2.196985  1.087410
# ...        ...       ...
# 1995  2.404659  2.348930
# 1996  1.979095  2.069483
# 1997  1.447904  1.524423
# 1998  2.477701  2.008892
# 1999  2.332858  2.324223
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-3, -1])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0.5, 1.5])

# %%
np.dot(W.T, X0)
# Out:
# -3.0

# %%
cov_inverse1 = np.linalg.inv(sd1)
cov_inverse2 = np.linalg.inv(sd2)

w1 = cov_inverse1.dot(mu1)
w2 = cov_inverse2.dot(mu2)

w = (w1.T-w2.T)
w1 = w[0]
w2=w[1]

w10 = (-1/2) * (mu1.T).dot(cov_inverse1).dot(mu1)
w20 = (-1/2) * (mu2.T).dot(cov_inverse2).dot(mu2)

x21 = np.linspace([-2,7],50)
x22 = ((w20-w10) - w1*x31)/w2

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(x21, x22, color='black')
axes.set_xlim(-4, 5)
axes.set_ylim(-1.5, 4.5)
# Out:
# (-1.5, 4.5)

# %% [markdown]
# **Conclusion :** Descision boundary is not parallel to y-axis contradictory to what is seen in the previous cases, but it is still linear in nature as the covariance matrix is same for both datasets.

# %% [markdown]
# ## c. Find the optimal decision boundary for the classification of the dataset A and B using
# ##  Σ1 =
# ## 0.6, 0.25
# ##0.25, 0.4
#
# ## Σ2 =
# ## 0.7, 0.25
# ##0.25, 0.35
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0.25],
                [0.25, 0.4]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.980794  0.756317
# 1    -0.974330  1.747449
# 2    -1.466621  0.918456
# 3    -1.656714  1.246427
# 4    -0.802599  0.995307
# ...        ...       ...
# 1995 -0.291441  1.125652
# 1996 -2.349883  0.933558
# 1997  0.134053  2.150026
# 1998 -0.176846  1.121750
# 1999 -0.578595  1.471721
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.7, 0.25],
                [0.25, 0.35]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     1.085847  1.989377
# 1     1.255055  1.350603
# 2     2.759635  2.376624
# 3     2.217902  1.596174
# 4     2.213300  1.607404
# ...        ...       ...
# 1995  2.595989  1.938209
# 1996  1.267834  1.924052
# 1997  2.540594  1.699085
# 1998  3.006138  2.116077
# 1999  1.417016  1.647734
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-3, -1])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0.5, 1.5])

# %%
np.dot(W.T, X0)
# Out:
# -3.0

# %%
cov_inverse1 = np.linalg.inv(sd1)
cov_inverse2 = np.linalg.inv(sd2)

w1 = cov_inverse1.dot(mu1)
w2 = cov_inverse2.dot(mu2)

w = (w1.T-w2.T)
w1 = w[0]
w2=w[1]

w10 = (-1/2) * (mu1.T).dot(cov_inverse1).dot(mu1)
w20 = (-1/2) * (mu2.T).dot(cov_inverse2).dot(mu2)

x31 = np.linspace([-2,7],50)
x32 = ((w20-w10) - w1*x31)/w2

# %%
fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(x31, x32, color='black')
axes.set_xlim(-4.5, 5)
axes.set_ylim(-1.5, 4.5)
# Out:
# (-1.5, 4.5)

# %% [markdown]
# **Conclusion :** Although covariance matrix is not same for both datasets.The Decision boundary is still linear in nature and parallel to y-axis.
