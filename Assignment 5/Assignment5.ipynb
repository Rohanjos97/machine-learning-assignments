# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohanjos97/machine-learning-assignments/blob/main/Assignment%205/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generate the datasets A and B in R2 with each of them consisting 2000 data points from normal distribution. The dataset A and B has been drawn from the N (μ1, Σ1 ) and N( μ2, Σ2 ). Let us fix the μ1 = [-1,1] and μ2 = [1,1].

# %% [markdown]
# ## a. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ##0.6, 0
#
# ## 0, 0.6
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pandas import DataFrame
from sklearn.datasets import make_blobs

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0],
                [0, 0.6]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A

# %%
mu2 = np.array([1, 1])
sd2 = np.array([[0.6, 0],
                [0, 0.6]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-2,  0])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0., 1.])

# %%
np.dot(W.T, X0)
# Out:
# 0.0

# %% [markdown]
# w1x1 + w2x2 + c = 0
# <br>
# w1 = -2
# <br>
# w2 = 0

# %%
X = np.zeros(100)

Y = np.random.uniform(-3, 4, 100)

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(X, Y, color='black')

# %% [markdown]
# ## b. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ## 0.7, 0
# ##0, 0.3
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.7, 0],
                [0, 0.3]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.896219  1.225615
# 1    -2.779371  1.172233
# 2    -0.639145  1.169877
# 3    -0.211221  1.421890
# 4    -0.474885 -0.176289
# ...        ...       ...
# 1995  0.517419  1.039322
# 1996 -1.210934  0.732322
# 1997 -2.249382  1.711283
# 1998  0.871500  1.807871
# 1999 -0.416700  0.602579
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.7, 0],
                [0, 0.3]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     2.085032  2.709676
# 1     2.404334  0.969970
# 2     2.296727  2.156964
# 3     2.669359  2.632573
# 4    -0.275885  2.125659
# ...        ...       ...
# 1995  2.227487  2.270041
# 1996  1.609475  1.605525
# 1997  2.482036  1.538024
# 1998  2.859738  1.568830
# 1999  2.193949  1.912374
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-3, -1])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0.5, 1.5])

# %%
np.dot(W.T, X0)
# Out:
# -3.0

# %% [markdown]
# w1x1 + w2x2 + c = 0
# <br>
# w1 = -2
# <br>
# w2 = 0

# %%
X = np.zeros(100)

Y = np.random.uniform(-3, 4, 100)

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(X, Y, color='black')

# %% [markdown]
# ## c. Find the optimal decision boundary for the classification of the dataset A and B using Σ1 = Σ2=
# ## 0.6, 0.25
# ##0.25, 0.4
#
# ## Plot the dataset A and B with different colors and plot the obtained optimal decision boundary. Comment on the characteristics of obtained decision boundary.

# %%
mu1 = np.array([-1, 1])
sd1 = np.array([[0.6, 0.25],
                [0.25, 0.4]])
A = np.random.multivariate_normal(mu1, sd1, 2000)
A = pd.DataFrame(A, columns=['0', '1'])
A
# Out:
#              0         1
# 0    -0.674952  1.192467
# 1    -0.862382 -0.367749
# 2    -1.964103  0.657983
# 3    -1.510699  1.122889
# 4    -1.184803  1.053072
# ...        ...       ...
# 1995 -0.378767  1.705118
# 1996 -0.829016  0.472162
# 1997 -1.486185  1.179871
# 1998 -1.324703  1.458638
# 1999 -1.281953  1.635779
#
# [2000 rows x 2 columns]

# %%
mu2 = np.array([2, 2])
sd2 = np.array([[0.6, 0.25],
                [0.25, 0.4]])
B = np.random.multivariate_normal(mu2, sd2, 2000)
B = pd.DataFrame(B, columns=['0', '1'])
B
# Out:
#              0         1
# 0     1.657605  1.647702
# 1     2.398842  1.966519
# 2     2.442928  1.603220
# 3     2.406309  2.411391
# 4     1.877840  1.214804
# ...        ...       ...
# 1995  2.757182  2.520464
# 1996  1.801640  1.347165
# 1997  0.271669  1.516462
# 1998  2.161282  2.749339
# 1999  2.722552  1.305385
#
# [2000 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 1, figsize=(10, 10))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')

# %%
W = mu1 - mu2
W
# Out:
# array([-3, -1])

# %%
X0 = 1/2 * (mu1 + mu2)
X0
# Out:
# array([0.5, 1.5])

# %%
np.dot(W.T, X0)
# Out:
# -3.0

# %% [markdown]
# w1x1 + w2x2 + c = 0
# <br>
# w1 = -2
# <br>
# w2 = 0

# %%
X = np.zeros(100)

Y = np.random.uniform(-3, 4, 100)

fig, axes = plt.subplots(1, 1, figsize=(13, 13))
axes.scatter(A['0'], A['1'], color='red')
axes.scatter(B['0'], B['1'], color='green')
axes.plot(X, Y, color='black')
